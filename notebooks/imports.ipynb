# %%
import maya4
# Out:
# Running cells with 'maya4-3.12 (Python 3.12.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/roberto.delprete/CODE/Maya4/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
